# %% [markdown]
# # Tournaments
#
# This creates a list of tournaments played in a given year range

# %%
import sys
import numpy as np
import pandas as pd
import time
from functions import getTournaments, getMatches, getPlayers, getRankings, getTournaments2

pd.set_option('expand_frame_repr', False)

# %% [markdown]
# ### Configuration
# Specify which years to generate tournament listings for

# %%
base_url = "http://www.atpworldtour.com/"
start_year = "2004"

# %% [markdown]
# ## Initialise the DataFrames

# %%
# Initialise an empty DataFrame with the columns we want
tournament_columns = ['Year', 'TourNo', 'Name', 'Date', 'Conditions', 'Surface', 'Prize', 'TournamentURL']
dfTours = pd.DataFrame([], columns = tournament_columns)

# Initialise an empty DataFrame with the columns we want
match_columns = ['TournamentID', 'MatchID', 'WinnerID', 'WinnerURL', 'WinnerName', 'WinnerSeed',
                                            'LoserID',  'LoserURL',  'LoserName',  'LoserSeed', 
                 'MatchURL']
dfMatches = pd.DataFrame([], columns=match_columns)

player_columns = ['PlayerID', 'Age', 'DoB', 'Weight', 'Height', 'YearWentPro', 'Hand', 'Backhand',
                  'TotalYTDWin', 'TotalYTDLoss', 'TotalAllWin', 'TotalAllLoss',
                  'ClayYTDWin', 'ClayYTDLoss', 'ClayAllWin', 'ClayAllLoss',
                  'GrassYTDWin', 'GrassYTDLoss', 'GrassAllWin', 'GrassAllLoss',
                  'HardYTDWin', 'HardYTDLoss', 'HardAllWin', 'HardAllLoss',
                  'CarpetYTDWin', 'CarpetYTDLoss', 'CarpetAllWin', 'CarpetAllLoss',
                  'IndoorYTDWin', 'IndoorYTDLoss', 'IndoorAllWin', 'IndoorAllLoss',
                  'OutdoorYTDWin', 'OutdoorYTDLoss', 'OutdoorAllWin', 'OutdoorAllLoss']
dfPlayers = pd.DataFrame([], columns = player_columns)

ranking_columns = ['PlayerID', 'MatchDate', 'Ranking']
dfRankings = pd.DataFrame([], columns = ranking_columns)

# %% [markdown]
# ### Tournament Listing
# Generate a list of the tournaments that occured for the specified years.
#
# For each tournament we store the following attributes:
#  * **Year** - What year did the tournament take place in?
#  * **TourNo** - An incrementing count of the touraments in the year
#  * **Name** - Name of the tournament
#  * **Date** - Date the tournament started
#  * **Conditions** - Outdoor or Indoor
#  * **Surface** - Hard, Clay, Grass etc
#  * **Prixe** - Prize money at stake
#  * **TournamentURL** - The URL where the tournament matches are listed
#
#  The combination of Year and a tournament number are combined to create a unique index called **TournamentID**.
#
#  The tournament listing is held in a Pandas DataFrame called dfTours.

# %%
# Iterate through the years and scrape tourney data
def getTournamentData(year):
    start_time = time.time()
    dfNewTours = pd.DataFrame(getTournaments(str(year)), columns = tournament_columns)
    end_time = time.time()
    print("Year " + year + ", Elapsed " + str(end_time-start_time))

    # Create an index of year plus tournament id
    dfNewTours['TournamentID'] = dfNewTours['TournamentURL'].str.split('\/').str[6] + "-" + dfNewTours['TournamentURL'].str.split('\/').str[5]
    dfNewTours = dfNewTours.set_index('TournamentID')

    return dfNewTours

# %% [markdown]
# ## Match Results
#
# Generate a list of the matches played in each tournament.
#
# For each match the following attributes are recorded:
#  * **TournamentID** - The unique index of dfTours
#  * **MatchID** - An ID assigned to that match.  Only unique within a tournament.
#  * **WinnerID** / **LoserID** - A unique player identifier.
#  * **WinnerURL** / **LoserURL** - The URL of the players details.
#  * **WinnerName** / **LoserName** - The players name.
#  * **WinnerSeed** / **LoserSeed** - If the player is seeded what seed were they?  "WC" represents wild-card.
#  * **MatchURL** - The URL where the detailed match statistics are available (not needed).
#
# A multi-index of **TournamentID** and **MatchID** can be used to uniquely identify a match.
#
# The match results are stored in a Pandas DataFrame called dfMatches.

# %%
# Iterate through each tournament and find the URLs with the match details
def getMatchData(dfTours):
    num_tournaments = len(dfTours)
    dfAllMatches = pd.DataFrame([], columns=match_columns)

    for counter in range(0,num_tournaments):
        start_time = time.time()

        tourney_url = dfTours.iloc[counter]['TournamentURL']

        tourney_id = tourney_url.split('/')[6] + "-" + tourney_url.split('/')[5]

        dfNewMatches = pd.DataFrame(getMatches(base_url, tourney_url+"?", tourney_id), columns = match_columns)

        if len(dfNewMatches) > 0:
            dfNewMatches['MatchNum'] = max(dfNewMatches.index) - dfNewMatches.index
        else:
            dfNewMatches['MatchNum'] = 0

        dfAllMatches = dfAllMatches.append(dfNewMatches)
        counter = counter+1
        end_time = time.time()
        print("Tournaments processed " + str(counter) + ", Elapsed " + str(end_time-start_time))

    dfAllMatches = dfAllMatches.set_index(['TournamentID', 'MatchID'])
    return dfAllMatches

# %% [markdown]
# ## Player URLs
#
# Generate a list of all the URLs where we can find the individual player statistics.  This will be held in a numpy array called playerURLs.

# %%
def getPlayerURLs(dfMatches):
    # Concatenate the list of WinnerURL's and LoserURL's from dfMatches and then ensure uniqueness.
    winnerURLs = dfMatches.as_matrix(columns=["WinnerURL"])
    loserURLs  = dfMatches.as_matrix(columns=["LoserURL"])

    return np.unique(np.concatenate((winnerURLs, loserURLs)))

# %% [markdown]
# ## Player Statistics
#
# Given a list of player URLs extract the following attributes for each player:
#  * **PlayerID**
#  * **Age**, **DOB**
#  * **Weight**
#  * **Height**
#  * **YearWentPro**
#  * **Hand**
#  * **Backhand**
#  * **TotalYTDWin**, **TotalYTDLoss**, **TotalAllWin**, **TotalAllLoss**
#  * **Clay**
#  * **Grass**
#  * **Hard**
#  * **Carpet**
#  * **Indoor**
#  * **Outdoor**
#
#  This data is held in a DataFrame called **dfPlayers**.

# %%
def getPlayerData(playerURLs):
    dfAllPlayers = pd.DataFrame([], columns = player_columns)
    num_players = len(playerURLs)
    batch_size = 50

    player_counter = 0
    while (player_counter * batch_size) < num_players:
        start_time = time.time()
        start_from = player_counter * batch_size
        end_at = min(start_from + batch_size, num_players)

        dfNewPlayers = pd.DataFrame(getPlayers(base_url, playerURLs[start_from:end_at]), columns = player_columns)
        # dfNewPlayers = dfNewPlayers.set_index(['PlayerID'])

        mid_time = time.time()
        if len(dfAllPlayers) == 0:
            dfAllPlayers = dfNewPlayers
        else:
            dfAllPlayers = dfAllPlayers.append(dfNewPlayers)
        player_counter = player_counter + 1
        end_time = time.time()
        print("Loop " + str(player_counter) + ", Start " + str(start_from) + ", Mid " + str(mid_time-start_time) + ", Elapsed " + str(end_time-start_time))

    dfAllPlayers = dfAllPlayers.set_index('PlayerID')
    return dfAllPlayers

# %% [markdown]
# ## Ranking Data
#
# Player world ranking varies over time.  For each player extract the history of their ranking:
#  * **PlayerID**
#  * **MatchDate**
#  * **Ranking**
#
# This data is held in a DataFrame called **dfRankings**.

# %%
def getRankingData(playerURLs):
    num_players = len(playerURLs)
    batch_size = 100
    dfAllRankings = pd.DataFrame([], columns = ranking_columns)

    counter = 0
    while (counter * batch_size) < num_players:
        start_time = time.time()
        start_from = counter * batch_size
        end_at = min(start_from + batch_size, num_players)
        dfNewRankings = pd.DataFrame(getRankings(base_url, playerURLs[start_from:end_at]), columns = ranking_columns)
        #dfNewRankings = dfNewRankings.set_index(['PlayerID','MatchDate'])

        if len(dfAllRankings) == 0:
            dfAllRankings = dfNewRankings
        else:
            dfAllRankings = dfAllRankings.append(dfNewRankings)

        counter = counter + 1
        end_time = time.time()
        print("Loop " + str(counter) + ", Start " + str(start_from) + ", Elapsed " + str(end_time-start_time))

    dfAllRankings = dfAllRankings.set_index(['PlayerID', 'MatchDate'])
    return dfAllRankings

# %% [markdown]
# # Get data for a year

# %%
def getDataForYear(year):
    dfTours = getTournamentData(year)
    dfTours.to_csv(path_or_buf="./data/dfTours_" + year + ".csv")
    
    dfMatches = getMatchData(dfTours)
    dfMatches.to_csv(path_or_buf="./data/dfMatches_" + year + ".csv")
    
    playerURLs = getPlayerURLs(dfMatches)
    
    dfPlayers = getPlayerData(playerURLs)
    dfPlayers.to_csv(path_or_buf="./data/dfPlayers_" + year + ".csv")

    dfRankings = getRankingData(playerURLs)
    dfRankings.to_csv(path_or_buf="./data/dfRankings_" + year + ".csv")
    
    return

# %%
getDataForYear("2016")
# Out:
# Year 2016, Elapsed 2.395132541656494
# Tournaments processed 1, Elapsed 0.2556595802307129
# Tournaments processed 2, Elapsed 0.24715399742126465
# Tournaments processed 3, Elapsed 0.20712542533874512
# Tournaments processed 4, Elapsed 0.20864152908325195
# Tournaments processed 5, Elapsed 0.2373206615447998
# Tournaments processed 6, Elapsed 1.9063615798950195
# Tournaments processed 7, Elapsed 0.2480926513671875
# Tournaments processed 8, Elapsed 0.2916078567504883
# Tournaments processed 9, Elapsed 0.23090577125549316
# Tournaments processed 10, Elapsed 0.22601842880249023
# Tournaments processed 11, Elapsed 0.23982024192810059
# Tournaments processed 12, Elapsed 0.24078631401062012
# Tournaments processed 13, Elapsed 0.25604844093322754
# Tournaments processed 14, Elapsed 0.2186870574951172
# Tournaments processed 15, Elapsed 0.26115918159484863
# Tournaments processed 16, Elapsed 0.21389460563659668
# Tournaments processed 17, Elapsed 0.23288393020629883
# Tournaments processed 18, Elapsed 0.24731731414794922
# Tournaments processed 19, Elapsed 0.23941993713378906
# Tournaments processed 20, Elapsed 0.2892146110534668
# Tournaments processed 21, Elapsed 0.24104809761047363
# Tournaments processed 22, Elapsed 0.247833251953125
# Tournaments processed 23, Elapsed 0.24892520904541016
# Tournaments processed 24, Elapsed 0.2561936378479004
# Tournaments processed 25, Elapsed 0.22771549224853516
# Tournaments processed 26, Elapsed 0.21312355995178223
# Tournaments processed 27, Elapsed 0.3000950813293457
# Tournaments processed 28, Elapsed 0.23878121376037598
# Tournaments processed 29, Elapsed 0.22972488403320312
# Tournaments processed 30, Elapsed 0.25163984298706055
# Tournaments processed 31, Elapsed 0.20583057403564453
# Tournaments processed 32, Elapsed 0.2583732604980469
# Tournaments processed 33, Elapsed 0.31171131134033203
# Tournaments processed 34, Elapsed 0.25092434883117676
# Tournaments processed 35, Elapsed 0.21539664268493652
# Tournaments processed 36, Elapsed 0.2254476547241211
# Tournaments processed 37, Elapsed 0.29531240463256836
# Tournaments processed 38, Elapsed 0.26628589630126953
# Tournaments processed 39, Elapsed 0.27429819107055664
# Tournaments processed 40, Elapsed 0.2447361946105957
# Tournaments processed 41, Elapsed 0.20718002319335938
# Tournaments processed 42, Elapsed 1.3240716457366943
# Tournaments processed 43, Elapsed 0.2308034896850586
# Tournaments processed 44, Elapsed 0.22894287109375
# Tournaments processed 45, Elapsed 0.19867944717407227
# Tournaments processed 46, Elapsed 0.25293469429016113
# Tournaments processed 47, Elapsed 0.3078160285949707
# Tournaments processed 48, Elapsed 0.2632782459259033
# Tournaments processed 49, Elapsed 0.2208855152130127
# Tournaments processed 50, Elapsed 0.22510695457458496
# Tournaments processed 51, Elapsed 0.21376943588256836
# Tournaments processed 52, Elapsed 0.23845148086547852
# Tournaments processed 53, Elapsed 0.2767672538757324
# Tournaments processed 54, Elapsed 0.2178478240966797
# Tournaments processed 55, Elapsed 1.2334105968475342
# Tournaments processed 56, Elapsed 0.21799588203430176
# Tournaments processed 57, Elapsed 0.21562719345092773
# Tournaments processed 58, Elapsed 0.21485638618469238
# Tournaments processed 59, Elapsed 0.22231197357177734
# Tournaments processed 60, Elapsed 0.26546621322631836
# Tournaments processed 61, Elapsed 1.1805884838104248
# Tournaments processed 62, Elapsed 0.6159369945526123
# Tournaments processed 63, Elapsed 0.2031402587890625
# Tournaments processed 64, Elapsed 0.22764992713928223
# Tournaments processed 65, Elapsed 0.2165238857269287
# Tournaments processed 66, Elapsed 0.2249152660369873
# Tournaments processed 67, Elapsed 1.1183936595916748
# Loop 1, Start 0, Mid 52.60548686981201, Elapsed 52.60548686981201
# Loop 2, Start 50, Mid 54.51535415649414, Elapsed 54.51635193824768
# Loop 3, Start 100, Mid 52.0810067653656, Elapsed 52.0810067653656
# Loop 4, Start 150, Mid 53.506550788879395, Elapsed 53.50754737854004
# Loop 5, Start 200, Mid 53.95413160324097, Elapsed 53.95413160324097
# Loop 6, Start 250, Mid 54.65299892425537, Elapsed 54.65299892425537
# Loop 7, Start 300, Mid 53.37880229949951, Elapsed 53.37982726097107
# Loop 8, Start 350, Mid 53.62557649612427, Elapsed 53.62657380104065
# Loop 9, Start 400, Mid 55.528209924697876, Elapsed 55.52920722961426
# Loop 10, Start 450, Mid 53.382837772369385, Elapsed 53.38383507728577
# Loop 11, Start 500, Mid 47.20302176475525, Elapsed 47.204020261764526
# Loop 1, Start 0, Elapsed 115.78521776199341
# Loop 2, Start 100, Elapsed 120.01944637298584
# Loop 3, Start 200, Elapsed 119.13645005226135
# Loop 4, Start 300, Elapsed 120.6122453212738
# Loop 5, Start 400, Elapsed 119.72574806213379
# Loop 6, Start 500, Elapsed 52.28692293167114

# %%
getDataForYear("2017")
# Out:
# Year 2017, Elapsed 1.1111490726470947
# Tournaments processed 1, Elapsed 0.2058241367340088
# Tournaments processed 2, Elapsed 0.4523494243621826
# Tournaments processed 3, Elapsed 0.2268376350402832
# Tournaments processed 4, Elapsed 0.21000957489013672
# Tournaments processed 5, Elapsed 0.22619128227233887
# Tournaments processed 6, Elapsed 1.6707687377929688
# Tournaments processed 7, Elapsed 0.2079932689666748
# Tournaments processed 8, Elapsed 0.228302001953125
# Tournaments processed 9, Elapsed 0.2393498420715332
# Tournaments processed 10, Elapsed 0.20876121520996094
# Tournaments processed 11, Elapsed 0.236907958984375
# Tournaments processed 12, Elapsed 0.21512460708618164
# Tournaments processed 13, Elapsed 0.2507929801940918
# Tournaments processed 14, Elapsed 0.23708462715148926
# Tournaments processed 15, Elapsed 0.20755839347839355
# Tournaments processed 16, Elapsed 0.9693701267242432
# Tournaments processed 17, Elapsed 0.20932412147521973
# Tournaments processed 18, Elapsed 0.23791027069091797
# Tournaments processed 19, Elapsed 0.294788122177124
# Tournaments processed 20, Elapsed 0.24597454071044922
# Tournaments processed 21, Elapsed 0.2057790756225586
# Tournaments processed 22, Elapsed 0.207869291305542
# Tournaments processed 23, Elapsed 0.343721866607666
# Tournaments processed 24, Elapsed 0.22327971458435059
# Tournaments processed 25, Elapsed 0.2354416847229004
# Tournaments processed 26, Elapsed 0.21003174781799316
# Tournaments processed 27, Elapsed 0.20425748825073242
# Tournaments processed 28, Elapsed 0.21038126945495605
# Tournaments processed 29, Elapsed 0.2585134506225586
# Tournaments processed 30, Elapsed 0.2058544158935547
# Tournaments processed 31, Elapsed 0.24822354316711426
# Tournaments processed 32, Elapsed 0.22324347496032715
# Tournaments processed 33, Elapsed 0.37288784980773926
# Tournaments processed 34, Elapsed 0.22081303596496582
# Tournaments processed 35, Elapsed 0.20904231071472168
# Tournaments processed 36, Elapsed 0.19826197624206543
# Tournaments processed 37, Elapsed 0.21497511863708496
# Tournaments processed 38, Elapsed 0.21480107307434082
# Tournaments processed 39, Elapsed 0.19971060752868652
# Tournaments processed 40, Elapsed 0.32873034477233887
# Tournaments processed 41, Elapsed 0.23345136642456055
# Tournaments processed 42, Elapsed 0.22345948219299316
# Tournaments processed 43, Elapsed 0.23716163635253906
# Tournaments processed 44, Elapsed 1.1022019386291504
# Tournaments processed 45, Elapsed 0.22879481315612793
# Tournaments processed 46, Elapsed 0.20823311805725098
# Tournaments processed 47, Elapsed 0.33366847038269043
# Tournaments processed 48, Elapsed 0.3501293659210205
# Tournaments processed 49, Elapsed 0.2524547576904297
# Tournaments processed 50, Elapsed 0.21695327758789062
# Tournaments processed 51, Elapsed 0.25647926330566406
# Tournaments processed 52, Elapsed 0.24685311317443848
# Tournaments processed 53, Elapsed 0.29373741149902344
# Tournaments processed 54, Elapsed 0.20058560371398926
# Tournaments processed 55, Elapsed 0.21512055397033691
# Tournaments processed 56, Elapsed 0.2106795310974121
# Tournaments processed 57, Elapsed 0.22296428680419922
# Tournaments processed 58, Elapsed 0.20421886444091797
# Tournaments processed 59, Elapsed 0.21311545372009277
# Tournaments processed 60, Elapsed 0.24019169807434082
# Tournaments processed 61, Elapsed 0.23370623588562012
# Tournaments processed 62, Elapsed 0.20878839492797852
# Tournaments processed 63, Elapsed 0.20215678215026855
# Tournaments processed 64, Elapsed 0.24059462547302246
# Tournaments processed 65, Elapsed 0.22772526741027832
# Tournaments processed 66, Elapsed 0.20478558540344238
# Tournaments processed 67, Elapsed 0.24120092391967773
# Tournaments processed 68, Elapsed 0.24168610572814941
# Tournaments processed 69, Elapsed 0.22948193550109863
# Loop 1, Start 0, Mid 25.904746294021606, Elapsed 25.904746294021606
# Loop 2, Start 50, Mid 25.021389961242676, Elapsed 25.02238702774048
# Loop 3, Start 100, Mid 20.80930519104004, Elapsed 20.80930519104004
# Loop 4, Start 150, Mid 19.916847467422485, Elapsed 19.916847467422485
# Loop 5, Start 200, Mid 18.509142637252808, Elapsed 18.509142637252808
# Loop 6, Start 250, Mid 19.858811378479004, Elapsed 19.859808683395386
# Loop 7, Start 300, Mid 19.46580934524536, Elapsed 19.466809272766113
# Loop 8, Start 350, Mid 26.148879289627075, Elapsed 26.14987826347351
# Loop 9, Start 400, Mid 22.878760814666748, Elapsed 22.878760814666748
# Loop 10, Start 450, Mid 18.883132696151733, Elapsed 18.883132696151733
# Loop 11, Start 500, Mid 15.340307712554932, Elapsed 15.341305255889893
# Loop 1, Start 0, Elapsed 55.01916289329529
# Loop 2, Start 100, Elapsed 42.394495487213135
# Loop 3, Start 200, Elapsed 43.78900694847107
# Loop 4, Start 300, Elapsed 43.62487268447876
# Loop 5, Start 400, Elapsed 46.45202684402466
# Loop 6, Start 500, Elapsed 17.148631811141968

# %%
getDataForYear("2018")
# Out:
# Year 2018, Elapsed 0.7504823207855225
# Tournaments processed 1, Elapsed 0.2162644863128662
# Tournaments processed 2, Elapsed 0.2238025665283203
# Tournaments processed 3, Elapsed 0.24199628829956055
# Tournaments processed 4, Elapsed 0.24570083618164062
# Tournaments processed 5, Elapsed 0.23999381065368652
# Tournaments processed 6, Elapsed 0.2627863883972168
# Tournaments processed 7, Elapsed 0.20903587341308594
# Tournaments processed 8, Elapsed 0.23115181922912598
# Tournaments processed 9, Elapsed 0.23227858543395996
# Tournaments processed 10, Elapsed 0.25591039657592773
# Tournaments processed 11, Elapsed 0.2123575210571289
# Tournaments processed 12, Elapsed 0.2212657928466797
# Tournaments processed 13, Elapsed 0.23500514030456543
# Tournaments processed 14, Elapsed 0.23789572715759277
# Tournaments processed 15, Elapsed 0.23879504203796387
# Tournaments processed 16, Elapsed 0.22511076927185059
# Tournaments processed 17, Elapsed 0.20586562156677246
# Tournaments processed 18, Elapsed 0.2317655086517334
# Tournaments processed 19, Elapsed 0.2696094512939453
# Tournaments processed 20, Elapsed 0.23109197616577148
# Tournaments processed 21, Elapsed 0.8311915397644043
# Tournaments processed 22, Elapsed 0.20783782005310059
# Tournaments processed 23, Elapsed 0.24642610549926758
# Tournaments processed 24, Elapsed 0.25624608993530273
# Tournaments processed 25, Elapsed 0.22608089447021484
# Tournaments processed 26, Elapsed 0.20736312866210938
# Tournaments processed 27, Elapsed 0.22348356246948242
# Tournaments processed 28, Elapsed 0.27002501487731934
# Tournaments processed 29, Elapsed 0.2267155647277832
# Tournaments processed 30, Elapsed 0.21892189979553223
# Tournaments processed 31, Elapsed 0.23400449752807617
# Tournaments processed 32, Elapsed 0.21789908409118652
# Tournaments processed 33, Elapsed 0.26590490341186523
# Tournaments processed 34, Elapsed 0.24362754821777344
# Tournaments processed 35, Elapsed 0.22276759147644043
# Tournaments processed 36, Elapsed 0.4224569797515869
# Tournaments processed 37, Elapsed 0.20139837265014648
# Tournaments processed 38, Elapsed 0.21126985549926758
# Tournaments processed 39, Elapsed 0.2200155258178711
# Tournaments processed 40, Elapsed 0.329359769821167
# Tournaments processed 41, Elapsed 0.19777178764343262
# Tournaments processed 42, Elapsed 0.2393028736114502
# Tournaments processed 43, Elapsed 0.20654726028442383
# Tournaments processed 44, Elapsed 0.21573948860168457
# Tournaments processed 45, Elapsed 0.21294236183166504
# Tournaments processed 46, Elapsed 0.22162437438964844
# Tournaments processed 47, Elapsed 0.21525788307189941
# Tournaments processed 48, Elapsed 0.22542691230773926
# Tournaments processed 49, Elapsed 0.23790931701660156
# Tournaments processed 50, Elapsed 0.23294997215270996
# Tournaments processed 51, Elapsed 0.23008370399475098
# Tournaments processed 52, Elapsed 0.2109668254852295
# Tournaments processed 53, Elapsed 0.2971971035003662
# Tournaments processed 54, Elapsed 0.2210679054260254
# Tournaments processed 55, Elapsed 0.27387499809265137
# Tournaments processed 56, Elapsed 0.1939849853515625
# Tournaments processed 57, Elapsed 0.24370384216308594
# Tournaments processed 58, Elapsed 0.2486886978149414
# Tournaments processed 59, Elapsed 0.24140501022338867
# Tournaments processed 60, Elapsed 1.2212505340576172
# Tournaments processed 61, Elapsed 0.29097461700439453
# Tournaments processed 62, Elapsed 0.23828434944152832
# Tournaments processed 63, Elapsed 0.22316813468933105
# Tournaments processed 64, Elapsed 0.20673036575317383
# Tournaments processed 65, Elapsed 0.21085500717163086
# Tournaments processed 66, Elapsed 0.25281429290771484
# Tournaments processed 67, Elapsed 0.23463916778564453
# Tournaments processed 68, Elapsed 0.20661640167236328
# Tournaments processed 69, Elapsed 0.2621889114379883
# Loop 1, Start 0, Mid 19.022666215896606, Elapsed 19.022666215896606
# Loop 2, Start 50, Mid 22.274089813232422, Elapsed 22.275086641311646
# Loop 3, Start 100, Mid 15.219751119613647, Elapsed 15.22074818611145
# Loop 4, Start 150, Mid 19.310673236846924, Elapsed 19.310673236846924
# Loop 5, Start 200, Mid 23.637795448303223, Elapsed 23.637795448303223
# Loop 6, Start 250, Mid 17.451738357543945, Elapsed 17.451738357543945
# Loop 7, Start 300, Mid 19.76384425163269, Elapsed 19.76384425163269
# Loop 8, Start 350, Mid 17.643093585968018, Elapsed 17.6440908908844
# Loop 9, Start 400, Mid 17.106276035308838, Elapsed 17.106276035308838
# Loop 10, Start 450, Mid 15.489354133605957, Elapsed 15.49034833908081
# Loop 11, Start 500, Mid 1.343230962753296, Elapsed 1.3442294597625732
# Loop 1, Start 0, Elapsed 45.08864998817444
# Loop 2, Start 100, Elapsed 37.18294978141785
# Loop 3, Start 200, Elapsed 47.03171730041504
# Loop 4, Start 300, Elapsed 45.1542227268219
# Loop 5, Start 400, Elapsed 35.0695013999939
# Loop 6, Start 500, Elapsed 1.4091262817382812

# %%
getDataForYear("2019")
# Out:
# Year 2019, Elapsed 2.3878793716430664
# Tournaments processed 1, Elapsed 0.22399520874023438
# Tournaments processed 2, Elapsed 0.21076107025146484
# Tournaments processed 3, Elapsed 0.207627534866333
# Tournaments processed 4, Elapsed 0.23376917839050293
# Tournaments processed 5, Elapsed 0.24065375328063965
# Tournaments processed 6, Elapsed 0.2195582389831543
# Tournaments processed 7, Elapsed 0.2166426181793213
# Tournaments processed 8, Elapsed 0.23970270156860352
# Tournaments processed 9, Elapsed 0.2239069938659668
# Tournaments processed 10, Elapsed 0.21102452278137207
# Tournaments processed 11, Elapsed 0.22275447845458984
# Tournaments processed 12, Elapsed 0.2181382179260254
# Tournaments processed 13, Elapsed 0.22945237159729004
# Tournaments processed 14, Elapsed 0.1970973014831543
# Tournaments processed 15, Elapsed 0.2325754165649414
# Tournaments processed 16, Elapsed 0.22622036933898926
# Tournaments processed 17, Elapsed 0.24321937561035156
# Tournaments processed 18, Elapsed 0.24246692657470703
# Tournaments processed 19, Elapsed 0.23931431770324707
# Tournaments processed 20, Elapsed 0.3048272132873535
# Tournaments processed 21, Elapsed 0.233506441116333
# Tournaments processed 22, Elapsed 0.23586630821228027
# Tournaments processed 23, Elapsed 0.2137000560760498
# Tournaments processed 24, Elapsed 0.22831463813781738
# Tournaments processed 25, Elapsed 0.22096633911132812
# Tournaments processed 26, Elapsed 0.20668792724609375
# Tournaments processed 27, Elapsed 0.2128145694732666
# Tournaments processed 28, Elapsed 0.24317312240600586
# Tournaments processed 29, Elapsed 0.226287841796875
# Tournaments processed 30, Elapsed 0.20785140991210938
# Tournaments processed 31, Elapsed 0.21720647811889648
# Tournaments processed 32, Elapsed 0.24259185791015625
# Tournaments processed 33, Elapsed 0.2105247974395752
# Tournaments processed 34, Elapsed 0.20629668235778809
# Tournaments processed 35, Elapsed 0.493182897567749
# Tournaments processed 36, Elapsed 0.9412937164306641
# Tournaments processed 37, Elapsed 0.23922038078308105
# Tournaments processed 38, Elapsed 0.22228431701660156
# Tournaments processed 39, Elapsed 0.24503827095031738
# Tournaments processed 40, Elapsed 1.3693408966064453
# Tournaments processed 41, Elapsed 0.23341012001037598
# Tournaments processed 42, Elapsed 0.22230982780456543
# Tournaments processed 43, Elapsed 0.22635293006896973
# Tournaments processed 44, Elapsed 0.23396849632263184
# Tournaments processed 45, Elapsed 0.21759605407714844
# Tournaments processed 46, Elapsed 1.3103928565979004
# Tournaments processed 47, Elapsed 0.5481622219085693
# Tournaments processed 48, Elapsed 0.20465302467346191
# Tournaments processed 49, Elapsed 0.24230742454528809
# Tournaments processed 50, Elapsed 0.23099970817565918
# Tournaments processed 51, Elapsed 0.21185827255249023
# Tournaments processed 52, Elapsed 0.26035022735595703
# Tournaments processed 53, Elapsed 0.19679665565490723
# Tournaments processed 54, Elapsed 0.2387557029724121
# Tournaments processed 55, Elapsed 0.22568488121032715
# Tournaments processed 56, Elapsed 0.21753787994384766
# Tournaments processed 57, Elapsed 0.19594359397888184
# Tournaments processed 58, Elapsed 0.21922826766967773
# Tournaments processed 59, Elapsed 0.23737812042236328
# Tournaments processed 60, Elapsed 0.24519681930541992
# Tournaments processed 61, Elapsed 0.21570229530334473
# Tournaments processed 62, Elapsed 0.20796585083007812
# Tournaments processed 63, Elapsed 0.26243138313293457
# Tournaments processed 64, Elapsed 0.9557735919952393
# Tournaments processed 65, Elapsed 1.6536831855773926
# Loop 1, Start 0, Mid 17.666147708892822, Elapsed 17.666147708892822
# Loop 2, Start 50, Mid 15.724827527999878, Elapsed 15.724827527999878
# Loop 3, Start 100, Mid 17.539044857025146, Elapsed 17.539044857025146
# Loop 4, Start 150, Mid 16.602182626724243, Elapsed 16.602182626724243
# Loop 5, Start 200, Mid 20.61511731147766, Elapsed 20.61511731147766
# Loop 6, Start 250, Mid 17.867191553115845, Elapsed 17.867191553115845
# Loop 7, Start 300, Mid 15.919368743896484, Elapsed 15.920366525650024
# Loop 8, Start 350, Mid 17.292842626571655, Elapsed 17.293840169906616
# Loop 9, Start 400, Mid 14.116771697998047, Elapsed 14.117769479751587
# Loop 1, Start 0, Elapsed 34.88320565223694
# Loop 2, Start 100, Elapsed 38.01804828643799
# Loop 3, Start 200, Elapsed 39.28864860534668
# Loop 4, Start 300, Elapsed 34.78296899795532
# Loop 5, Start 400, Elapsed 14.856384038925171

# %% [markdown]
# # Run Data Download

# %%
dfTours = getTournamentData(start_year)
print(dfTours)
dfTours.to_csv(path_or_buf="./data/dfTours_" + start_year + ".csv")
# Out:
# Year 2004, Elapsed 0.2774839401245117
#               Year TourNo                           Name        Date Conditions Surface       Prize                                      TournamentURL
# TournamentID
# 2004-451      2004      1                           Doha  2004.01.05    Outdoor    Hard  $1,000,000           /en/scores/archive/doha/451/2004/results
# 2004-890      2004     58                       Shanghai  2004.09.27    Outdoor    Hard    $380,000       /en/scores/archive/shanghai/890/2004/results
# 2004-7309     2004     59                           Lyon  2004.10.04     Indoor  Carpet    $791,750          /en/scores/archive/lyon/7309/2004/results
# 2004-329      2004     60                          Tokyo  2004.10.04    Outdoor    Hard    $775,000          /en/scores/archive/tokyo/329/2004/results
# 2004-438      2004     61                         Moscow  2004.10.11     Indoor  Carpet  $1,000,000         /en/scores/archive/moscow/438/2004/results
# 2004-337      2004     62                         Vienna  2004.10.11     Indoor    Hard    $682,750         /en/scores/archive/vienna/337/2004/results
# 2004-341      2004     63                           Metz  2004.10.11     Indoor    Hard    $380,000           /en/scores/archive/metz/341/2004/results
# 2004-1536     2004     64        ATP Masters 1000 Madrid  2004.10.18     Indoor    Hard  $2,425,500        /en/scores/archive/madrid/1536/2004/results
# 2004-328      2004     65                          Basel  2004.10.25     Indoor  Carpet  $1,000,000          /en/scores/archive/basel/328/2004/results
# 2004-568      2004     66                 St. Petersburg  2004.10.25     Indoor  Carpet  $1,000,000  /en/scores/archive/st-petersburg/568/2004/results
# 2004-429      2004     67                      Stockholm  2004.10.25     Indoor    Hard    $643,750      /en/scores/archive/stockholm/429/2004/results
# 2004-352      2004     68         ATP Masters 1000 Paris  2004.11.01     Indoor  Carpet  $2,425,500          /en/scores/archive/paris/352/2004/results
# 2004-605      2004     69             Tennis Masters Cup  2004.11.15    Outdoor    Hard  $3,700,000  /en/scores/archive/tennis-masters-cup/605/2004...
#
# [69 rows x 8 columns]

# %%
dfMatches = getMatchData(dfTours)
print(dfMatches)
dfMatches.to_csv(path_or_buf="./data/dfMatches_" + start_year + ".csv")
# Out:
# Tournaments processed 1, Elapsed 1.351186752319336
# Tournaments processed 2, Elapsed 1.203507423400879
# Tournaments processed 3, Elapsed 0.897174596786499
# Tournaments processed 4, Elapsed 1.2089507579803467
# Tournaments processed 5, Elapsed 1.163109302520752
# Tournaments processed 6, Elapsed 1.4121582508087158
# Tournaments processed 7, Elapsed 1.317711591720581
# Tournaments processed 8, Elapsed 1.350632667541504
# Tournaments processed 9, Elapsed 1.5317957401275635
# Tournaments processed 10, Elapsed 1.1874752044677734
# Tournaments processed 11, Elapsed 3.3351454734802246
# Tournaments processed 12, Elapsed 1.2302637100219727
# Tournaments processed 13, Elapsed 1.3520641326904297
# Tournaments processed 14, Elapsed 1.3263823986053467
# Tournaments processed 15, Elapsed 1.2967503070831299
# Tournaments processed 16, Elapsed 1.4118127822875977
# Tournaments processed 17, Elapsed 1.303405523300171
# Tournaments processed 18, Elapsed 1.435990333557129
# Tournaments processed 19, Elapsed 1.691483497619629
# Tournaments processed 20, Elapsed 1.7403209209442139
# Tournaments processed 21, Elapsed 1.185683012008667
# Tournaments processed 22, Elapsed 1.2078068256378174
# Tournaments processed 23, Elapsed 1.0512111186981201
# Tournaments processed 24, Elapsed 1.2478010654449463
# Tournaments processed 25, Elapsed 1.151451826095581
# Tournaments processed 26, Elapsed 1.3516488075256348
# Tournaments processed 27, Elapsed 1.5807304382324219
# Tournaments processed 28, Elapsed 1.0139403343200684
# Tournaments processed 29, Elapsed 1.1482160091400146
# Tournaments processed 30, Elapsed 1.1747708320617676
# Tournaments processed 31, Elapsed 1.512010097503662
# Tournaments processed 32, Elapsed 1.3635754585266113
# Tournaments processed 33, Elapsed 1.1883914470672607
# Tournaments processed 34, Elapsed 1.4323208332061768
# Tournaments processed 35, Elapsed 1.3132400512695312
# Tournaments processed 36, Elapsed 1.5439918041229248
# Tournaments processed 37, Elapsed 1.3335468769073486
# Tournaments processed 38, Elapsed 1.308624267578125
# Tournaments processed 39, Elapsed 1.1777682304382324
# Tournaments processed 40, Elapsed 1.3165698051452637
# Tournaments processed 41, Elapsed 1.1737034320831299
# Tournaments processed 42, Elapsed 1.4897890090942383
# Tournaments processed 43, Elapsed 1.3596422672271729
# Tournaments processed 44, Elapsed 1.1939072608947754
# Tournaments processed 45, Elapsed 1.2020783424377441
# Tournaments processed 46, Elapsed 1.4980640411376953
# Tournaments processed 47, Elapsed 1.319185495376587
# Tournaments processed 48, Elapsed 1.1817522048950195
# Tournaments processed 49, Elapsed 1.2370502948760986
# Tournaments processed 50, Elapsed 1.3425202369689941
# Tournaments processed 51, Elapsed 1.1498639583587646
# Tournaments processed 52, Elapsed 1.4599056243896484
# Tournaments processed 53, Elapsed 1.2153820991516113
# Tournaments processed 54, Elapsed 1.2954859733581543
# Tournaments processed 55, Elapsed 1.2421083450317383
# Tournaments processed 56, Elapsed 1.1513166427612305
# Tournaments processed 57, Elapsed 1.1596767902374268
# Tournaments processed 58, Elapsed 1.3543617725372314
# Tournaments processed 59, Elapsed 1.211751937866211
# Tournaments processed 60, Elapsed 1.3073136806488037
# Tournaments processed 61, Elapsed 1.1981260776519775
# Tournaments processed 62, Elapsed 1.2159733772277832
# Tournaments processed 63, Elapsed 1.3710319995880127
# Tournaments processed 64, Elapsed 1.196842908859253
# Tournaments processed 65, Elapsed 1.1533987522125244
# Tournaments processed 66, Elapsed 1.349217414855957
# Tournaments processed 67, Elapsed 1.2063496112823486
# Tournaments processed 68, Elapsed 1.4013876914978027
# Tournaments processed 69, Elapsed 1.102405309677124
#                                        LoserID            LoserName LoserSeed                              LoserURL  MatchNum                                           MatchURL                  WinnerID           WinnerName WinnerSeed                             WinnerURL
# TournamentID MatchID
# 2004-451     MS001          ivan-ljubicic:l360        Ivan Ljubicic                  /en/players/ivan-ljubicic/l360      30.0  /en/scores/2004/451/MS001/match-stats?isLive=F...       nicolas-escude:e140       Nicolas Escude         WC       /en/players/nicolas-escude/e140
#              MS003             tim-henman:h336           Tim Henman         7           /en/players/tim-henman/h336      29.0  /en/scores/2004/451/MS003/match-stats?isLive=F...        ivan-ljubicic:l360        Ivan Ljubicic                   /en/players/ivan-ljubicic/l360
#              MS002        agustin-calleri:c478      Agustin Calleri         8      /en/players/agustin-calleri/c478      28.0  /en/scores/2004/451/MS002/match-stats?isLive=F...       nicolas-escude:e140       Nicolas Escude         WC       /en/players/nicolas-escude/e140
#              MS038            taylor-dent:d362          Taylor Dent                    /en/players/taylor-dent/d362       4.0  /en/scores/2004/352/MS038/match-stats?isLive=F...      robin-soderling:sa49      Robin Soderling                 /en/players/robin-soderling/sa49
#              MS041       mariano-zabaleta:z073     Mariano Zabaleta        AL     /en/players/mariano-zabaleta/z073       3.0  /en/scores/2004/352/MS041/match-stats?isLive=F...  paradorn-srichaphan:s675  Paradorn Srichaphan             /en/players/paradorn-srichaphan/s675
#              MS046         michael-llodra:l428       Michael Llodra                 /en/players/michael-llodra/l428       2.0  /en/scores/2004/352/MS046/match-stats?isLive=F...       radek-stepanek:s694       Radek Stepanek          Q       /en/players/radek-stepanek/s694
#              MS053            mario-ancic:a385          Mario Ancic                    /en/players/mario-ancic/a385       1.0  /en/scores/2004/352/MS053/match-stats?isLive=F...   jo-wilfried-tsonga:t786   Jo-Wilfried Tsonga          Q   /en/players/jo-wilfried-tsonga/t786
#              MS042         jonas-bjorkman:b446       Jonas Bjorkman                 /en/players/jonas-bjorkman/b446       0.0  /en/scores/2004/352/MS042/match-stats?isLive=F...      mikhail-youzhny:y061      Mikhail Youzhny                 /en/players/mikhail-youzhny/y061
# 2004-605     MS001         lleyton-hewitt:h432       Lleyton Hewitt         3       /en/players/lleyton-hewitt/h432       0.0  /en/scores/2004/605/MS001/match-stats?isLive=F...        roger-federer:f324        Roger Federer          1        /en/players/roger-federer/f324
#
# [2727 rows x 10 columns]

# %%
playerURLs = getPlayerURLs(dfMatches)

# %%
dfPlayers = getPlayerData(playerURLs)
dfPlayers.to_csv(path_or_buf="./data/dfPlayers_" + start_year + ".csv")
# Out:
# Loop 1, Start 0, Mid 55.430259227752686, Elapsed 55.430259227752686
# Loop 2, Start 50, Mid 57.554909229278564, Elapsed 57.554909229278564
# Loop 3, Start 100, Mid 55.859797954559326, Elapsed 55.859797954559326
# Loop 4, Start 150, Mid 55.57727241516113, Elapsed 55.57727241516113
# Loop 5, Start 200, Mid 54.706568479537964, Elapsed 54.707566022872925
# Loop 6, Start 250, Mid 53.294530153274536, Elapsed 53.294530153274536
# Loop 7, Start 300, Mid 40.586875677108765, Elapsed 40.586875677108765

# %%
dfRankings = getRankingData(playerURLs)
dfRankings.to_csv(path_or_buf="./data/dfRankings_" + start_year + ".csv")
# Out:
# Loop 1, Start 0, Elapsed 228.5743372440338
# Loop 2, Start 100, Elapsed 128.24384951591492
# Loop 3, Start 200, Elapsed 125.87894868850708
# Loop 4, Start 300, Elapsed 46.32646441459656

# %% [markdown]
# # Load Datasets from File

# %%
dfTours = pd.DataFrame.from_csv(path="./data/dfTours_2002.csv", encoding="mbcs", index_col=0)
dfMatches = pd.DataFrame.from_csv(path="./data/dfMatches_2002.csv", encoding="mbcs", index_col=[0,1])
#dfPlayers = pd.DataFrame.from_csv(path="./dfPlayers.csv", encoding="mbcs", index_col=0)
#dfRankings = pd.DataFrame.from_csv(path="./dfRankings.csv", encoding="mbcs", index_col=[0,1])

#winnerURLs = dfMatches.as_matrix(columns=["WinnerURL"])
#loserURLs  = dfMatches.as_matrix(columns=["LoserURL"])
#playerURLs = np.unique(np.concatenate((winnerURLs, loserURLs)))

# %%
dfMatches
# Out:
#                                              LoserID                  LoserName LoserSeed                                    LoserURL  MatchNum                                           MatchURL                  WinnerID           WinnerName WinnerSeed                             WinnerURL
# TournamentID MatchID
# 2002-451     MS001               felix-mantilla:m535             Felix Mantilla         8             /en/players/felix-mantilla/m535      30.0  /en/scores/2002/451/MS001/match-stats?isLive=F...    younes-el-aynaoui:e121    Younes El Aynaoui          6    /en/players/younes-el-aynaoui/e121
#              MS003              bohdan-ulihrach:u032            Bohdan Ulihrach         5            /en/players/bohdan-ulihrach/u032      29.0  /en/scores/2002/451/MS003/match-stats?isLive=F...       felix-mantilla:m535       Felix Mantilla          8       /en/players/felix-mantilla/m535
#              MS002            rainer-schuettler:s636          Rainer Schuettler         7          /en/players/rainer-schuettler/s636      28.0  /en/scores/2002/451/MS002/match-stats?isLive=F...    younes-el-aynaoui:e121    Younes El Aynaoui          6    /en/players/younes-el-aynaoui/e121
#              MS004           yevgeny-kafelnikov:k267         Yevgeny Kafelnikov         1         /en/players/yevgeny-kafelnikov/k267      27.0  /en/scores/2002/451/MS004/match-stats?isLive=F...    rainer-schuettler:s636    Rainer Schuettler          7    /en/players/rainer-schuettler/s636
#              MS005                   jiri-novak:n254                 Jiri Novak         4                 /en/players/jiri-novak/n254      26.0  /en/scores/2002/451/MS005/match-stats?isLive=F...    younes-el-aynaoui:e121    Younes El Aynaoui          6    /en/players/younes-el-aynaoui/e121
#              MS006             fernando-vicente:v195           Fernando Vicente       NaN           /en/players/fernando-vicente/v195      25.0  /en/scores/2002/451/MS006/match-stats?isLive=F...      bohdan-ulihrach:u032      Bohdan Ulihrach          5      /en/players/bohdan-ulihrach/u032
#              MS007               radek-stepanek:s694             Radek Stepanek         Q             /en/players/radek-stepanek/s694      24.0  /en/scores/2002/451/MS007/match-stats?isLive=F...       felix-mantilla:m535       Felix Mantilla          8       /en/players/felix-mantilla/m535
#              MS008            nikolay-davydenko:d402          Nikolay Davydenko       NaN          /en/players/nikolay-davydenko/d402      23.0  /en/scores/2002/451/MS008/match-stats?isLive=F...   yevgeny-kafelnikov:k267   Yevgeny Kafelnikov          1   /en/players/yevgeny-kafelnikov/k267
#              MS015             goran-ivanisevic:i034           Goran Ivanisevic         2           /en/players/goran-ivanisevic/i034      22.0  /en/scores/2002/451/MS015/match-stats?isLive=F...       radek-stepanek:s694       Radek Stepanek          Q       /en/players/radek-stepanek/s694
#              MS010                antony-dupuis:d272              Antony Dupuis       NaN              /en/players/antony-dupuis/d272      21.0  /en/scores/2002/451/MS010/match-stats?isLive=F...           jiri-novak:n254           Jiri Novak          4           /en/players/jiri-novak/n254
#              MS012               jonas-bjorkman:b446             Jonas Bjorkman       NaN             /en/players/jonas-bjorkman/b446      20.0  /en/scores/2002/451/MS012/match-stats?isLive=F...      bohdan-ulihrach:u032      Bohdan Ulihrach          5      /en/players/bohdan-ulihrach/u032
